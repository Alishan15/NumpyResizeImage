# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image as im

for i in range(21):
    img=mpimg.imread("C:\\Users\\Ali Shaan\\Desktop\\QUARTER 2\\images\\"+str(i+1)+".jpg")
    imgplot=plt.imshow(img)
    plt.show()
    
list1=[]
for i in range(20):
    im1=(im.open("C:\\Users\\Ali Shaan\\Desktop\\QUARTER 2\\images\\"+str(i+1)+".jpg"))
    im1=im1.resize((500,500),im.ANTIALIAS)
    im1.save("resize"+str(i+1)+".jpg")
    list1.append(np.array(im1))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-dee9d9058d5e> in <module>
#       5
#       6 for i in range(21):
# ----> 7     img=mpimg.imread("C:\\Users\\Ali Shaan\\Desktop\\QUARTER 2\\images\\"+str(i+1)+".jpg")
#       8     imgplot=plt.imshow(img)
#       9     plt.show()
#
# D:\Anaconda\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1349                              'with Pillow installed matplotlib can handle '
#    1350                              'more images' % list(handlers))
# -> 1351         with Image.open(fname) as image:
#    1352             return pil_to_array(image)
#    1353
#
# D:\Anaconda\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2632
#    2633     if filename:
# -> 2634         fp = builtins.open(filename, "rb")
#    2635         exclusive_fp = True
#    2636
#
# ...
